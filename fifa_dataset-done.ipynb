# %% [markdown]
# **************************************
# WELCOME TO MY PROJECT ON SOCCER DATASETS
# *************************************

# %% [markdown]
# IMPORT PYTHON LIBRARIES :

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# LOAD DATASETS :

# %%
fifa_df = pd.read_csv("C:\\Users\\JANESAR\\Desktop\\fifa_players_20.csv")
fifa_df.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 6     192448  https://sofifa.com/player/192448/marc-andre-te...
# 7     203376  https://sofifa.com/player/203376/virgil-van-di...
# 8     177003  https://sofifa.com/player/177003/luka-modric/2...
# 9     209331  https://sofifa.com/player/209331/mohamed-salah...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...

# %% [markdown]
# TOTAL COLUMNS IN DATAFRAME :?

# %%
for col in fifa_df.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %% [markdown]
# FIND TOTAL RECORDS AND COLUMNS IN  DATASETS :?

# %%
fifa_df.shape
# Out:
# (18278, 104)

# %% [markdown]
# TOP TEN NATIONALITY THESE PLAYERS BELONGS TO. :

# %%
fifa_df["nationality"].value_counts()[: 10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
fifa_df["nationality"].value_counts()[: 10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object')

# %% [markdown]
# DRAW BAR PLOT OF TOP TEN NATIOANLITY'S PLAYERS

# %%
plt.figure(figsize=(8, 5))
plt.bar(fifa_df["nationality"].value_counts()[0:5].keys(), (fifa_df["nationality"].value_counts()[0:5]), color="r")
plt.show()

# %% [markdown]
# TOP MAX SALARY PLAYER

# %%
max_player_salary = fifa_df[["short_name", "wage_eur"]]
# max_player_salary.short_values(by=["wage_eur"], ascending=False)
max_player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
max_player_salary = max_player_salary.sort_values(by=[ "wage_eur"], ascending=False )
max_player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
#Dreaw a bar plot for above question :-
plt.figure(figsize=(8, 4))
plt.bar((max_player_salary["short_name"])[0:5], (max_player_salary["wage_eur"])[0:5], color="g")
plt.show()

# %% [markdown]
# PLAYERS WHOSE NATIONALITY IS GERMANY :-

# %%
Germany_players = fifa_df[fifa_df["nationality"]=="Germany"]
Germany_players.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31        M. Neuer           Manuel Neuer   33  1986-03-27        193
# ...

# %% [markdown]
# WHO IS TALLEST GERMAN PLAYER :- ?

# %%
Germany_players.sort_values(by=["height_cm"], ascending=False).head(10)
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 13635     208776  https://sofifa.com/player/208776/florian-strit...
# 4449      158657  https://sofifa.com/player/158657/thomas-kessle...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 11147     235018  https://sofifa.com/player/235018/moritz-nicola...
# 16184     240218  https://sofifa.com/player/240218/alexander-wei...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# ...

# %% [markdown]
# FIND GERMAN PLAYERS WITH MAXIMUM WEIGHT IN KG :- ?

# %%
Germany_players.sort_values(by=["weight_kg"], ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# 1389   L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 518      R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
# 1217        M. Esser    Michael Esser   31  1987-11-22        198         97
# 77           N. Süle      Niklas Süle   23  1995-09-03        195         97
#
#       nationality                club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %% [markdown]
# TOP MOST EARNING GERMAN PLAYER :- ?

# %%
Germany_players.sort_values(by=["wage_eur"], ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
#
#         short_name              long_name  age         dob  height_cm  \
# 36        T. Kroos             Toni Kroos   29  1990-01-04        183
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 55         L. Sané             Leroy Sané   23  1996-01-11        183
# 146    I. Gündoğan         İlkay Gündoğan   28  1990-10-24        180
# 70       T. Müller          Thomas Müller   29  1989-09-13        186
#
#      weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# ...

# %% [markdown]
# FIND MAX SALARY OF GERMAN PLAYERS :- ?

# %%
Germany_players[["short_name", "wage_eur"]].sort_values(by=["wage_eur"], ascending=False).head(20)
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000
# 37         M. Reus    170000
# 31        M. Neuer    155000
# 215     S. Khedira    135000
# 49      M. Hummels    130000
# 135        M. Özil    125000
# 143     J. Boateng    125000
# 61      J. Kimmich    125000
# 117    L. Goretzka    120000
# 120      S. Gnabry    120000
# 77         N. Süle    115000
# 263     A. Rüdiger    115000
# 338         E. Can    110000
# 217       M. Kruse    105000
# 180     J. Draxler    100000
# 270       M. Götze     98000

# %% [markdown]
# FIND TOP 5 SHOOTING PLAYERS :- ?

# %%
shooting_players = fifa_df[["short_name", "shooting"]]
shooting_players.head()
# Out:
#           short_name  shooting
# 0           L. Messi      92.0
# 1  Cristiano Ronaldo      93.0
# 2          Neymar Jr      85.0
# 3           J. Oblak       NaN
# 4          E. Hazard      83.0

# %%
#top five best shooting players :
shooting_players.sort_values(by=["shooting"],  ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %% [markdown]
# TOP FIVE BEST DEFENDING SKILLS : - ?

# %%
defending_players = fifa_df[["short_name", "defending", "nationality", "club"]]
defending_players.sort_values(by=["defending"], ascending=False)
defending_players.head()
# Out:
#           short_name  defending nationality                 club
# 0           L. Messi       39.0   Argentina         FC Barcelona
# 1  Cristiano Ronaldo       35.0    Portugal             Juventus
# 2          Neymar Jr       32.0      Brazil  Paris Saint-Germain
# 3           J. Oblak        NaN    Slovenia      Atlético Madrid
# 4          E. Hazard       35.0     Belgium          Real Madrid

# %% [markdown]
# Now, analysi with Real Madrid club players :- ?
# 1- Top highest paid players in Real Madrid?

# %%
real_madrid = fifa_df[fifa_df["club"]=="Real Madrid"]
real_madrid.sort_values(by=["wage_eur"], ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46     165153  https://sofifa.com/player/165153/karim-benzema...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 46    K. Benzema        Karim Benzema   31  1987-12-19        185         81
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# ...

# %% [markdown]
# Top five best shooting skills players in Real MAdrid :- ?

# %%
real_madrid.sort_values(by=["shooting"], ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...
#
#        short_name                    long_name  age         dob  height_cm  \
# 100       G. Bale            Gareth Frank Bale   29  1989-07-16        185
# 106  J. Rodríguez  James David Rodríguez Rubio   27  1991-07-12        180
# 4       E. Hazard                  Eden Hazard   28  1991-01-07        175
# 46     K. Benzema                Karim Benzema   31  1987-12-19        185
# 161      L. Jović                   Luka Jović   21  1997-12-23        182
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %% [markdown]
# top five best Defender players in Real Madrid ;- ?

# %%
real_madrid.sort_values(by=["defending"], ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...
# 76      201535  https://sofifa.com/player/201535/raphael-varan...
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...
# 332     240130  https://sofifa.com/player/240130/eder-gabriel-...
#
#        short_name                          long_name  age         dob  \
# 18   Sergio Ramos                Sergio Ramos García   33  1986-03-30
# 42       Casemiro  Carlos Henrique Venancio Casimiro   27  1992-02-23
# 76      R. Varane                     Raphaël Varane   26  1993-04-25
# 94       Carvajal              Daniel Carvajal Ramos   27  1992-01-11
# 332  Éder Militão               Éder Gabriel Militão   21  1998-01-18
#
#      height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# ...

# %% [markdown]
# How many players from which nationality came to Real Madrid :- ?

# %%
real_madrid["nationality"].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: nationality, dtype: int64

# %% [markdown]
# ******************************
# THANKYOU
# ******************************

# %% [markdown]
# **************************
# JANESAR KHAN
# **************************
